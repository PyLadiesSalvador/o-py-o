# %% [markdown]
# ## Materiais recomendados:
#
#     documentação pandas: https://pandas.pydata.org/docs
#
# ### Vídeos com tutorias para iniciantes em português:
#
# [Playlist Dicas de Pandas do canal Programação Dinâmica](https://www.youtube.com/watch?v=MVd1cs7TDgA&list=PL5TJqBvpXQv6SSsEgQrNwpOLTupXPuiMQ&ab_channel=Programa%C3%A7%C3%A3oDin%C3%A2mica)
#
# [Pandas do Zero a Análise de Dados, Progamação Dinâmica](https://www.youtube.com/watch?v=wnGsAOPKjLo&t=4374s&ab_channel=Programa%C3%A7%C3%A3oDin%C3%A2mica)
#
# [Introdução ao Pandas no Python, Hashtag Programação](https://www.youtube.com/watch?v=C0aj3FjN5e0&t=2294s&ab_channel=HashtagPrograma%C3%A7%C3%A3o)
#
# [Playlist Análise de Dados em Python, LABHacker - Câmara dos Deputados](https://www.youtube.com/watch?v=W_Bz7M91R1Q&list=PLqiFjCF_dtcymXtdjwAP4s7tRoW4CYwnH&ab_channel=LABHacker-C%C3%A2maradosDeputados)
#
# ### Canais com videos em ingles com tutoriais de Pandas e de outras bibliotecas de análise de dados:
#
# [Medallion Data Science](https://www.youtube.com/channel/UCxladMszXan-jfgzyeIMyvw)
#
# [Corey Schafer](https://www.youtube.com/c/Coreyms/videos)
#
# [Data School](https://www.youtube.com/c/dataschool)
#
# [Kimberly Fessel](https://www.youtube.com/c/KimberlyFessel) - Tutoriais excelentes sobre bibliotecas de visualização de dados!
#
# ### Curso de Introduação a Ciência da Computação que recomendo demais, CS50:
#
# [Playlist com as aulas de 2015 com legendas em português](https://www.youtube.com/watch?v=SYZkrqW8oJc&list=PLRqGANMTmslTVwZA-H7aDiiNACau3yhVH&ab_channel=estude.org)
#
# [Canal do CS50](https://www.youtube.com/c/cs50/videos) - muitos vídeos do curso de vários anos diferentes e também vídeos específivos de python e outras coisas. Eu consegui engajar no [curso de 2020](https://www.youtube.com/watch?v=YoXxevp1WRQ&list=PLhQjrBD2T382_R182iC2gNZI9HzWFMC_8&ab_channel=CS50) que as aulas foram feitas para ser curso online, mas estão em inglês.
#
#
# ### Duas pessoas incríveis que me ensinam (sigo aprendendo!) como trabalhar com Pandas de maneira eficiente:
#
# [Podcast com Hannah Stepanek](https://www.youtube.com/watch?v=NOBn8r5t5A4&ab_channel=RealPython)
# [Hannah Stepanek](https://www.youtube.com/watch?v=ObUcgEO4N8w&list=PLme3Mg2BIyCWh7TOHB1-jEaz4PpN5Alw6&index=18&t=290s&ab_channel=PyCon2019) - o livro dela é: Thinking in Pandas: How to Use the Python Data Analysis Library the Right Way.
#
# [Podcast com Matt Harrison](https://www.youtube.com/watch?v=_4xwSRqPxLo&ab_channel=SuperDataSciencePodcastwithJonKrohn)
# [Matt Harrison](https://www.youtube.com/watch?v=zgbUk90aQ6A&t=2496s&ab_channel=PyData) - o livro dele mais recente é: Effective Pandas: Patterns for Data Manipulation.
#
# ### Livro sobre ciência de dados com python (não tive tempo de analisar, mas parece bom):
#
# [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/)
#
# ### Canais de encontros de python para trabalhar com dados que me fizeram encontrar as pessoas incríveis que me ensinam tanto:
#
# [PyData](https://www.youtube.com/c/PyDataTV/videos)
#
# ### PyCon - são muitos canais dessas conferências de python, busquem por pycon no youtube.
#
# [pythonbrasil](https://www.youtube.com/c/pythonbrasiloficial)
#
# ### Podcasts de Python/Dados ou tecnologia em geral:
#
# [Pizza de Dados](https://open.spotify.com/show/5k0Ei0MSg5BuiHshr43aSg)
#
# [Feministech Podcast](https://open.spotify.com/show/5C1LL8H7iFCmUCoEmGJkd5)
#
# [Podprogramar Podcast](https://open.spotify.com/show/16ZtU9p6Pja5H87W35owjY)
#
# [Epopeia Tech Podcast](https://open.spotify.com/show/1d7LxF2CpMgGMozK9uxNyz)
#
# [DataHackers Podcast](https://open.spotify.com/show/1oMIHOXsrLFENAeM743g93)
#
# [Hipster ponto tech Podcast](https://open.spotify.com/show/2p0Vx75OmfsXktyLBuLuSf)
#
# [Show me the Data](https://www.youtube.com/watch?v=7d5OK23TNYY&list=PLZlkyCIi8bMrphEn1evKBGDm159oU6sb6&ab_channel=SejaUmDataScientist)
#
# [Tecnopolítica](https://open.spotify.com/show/55uTHZA0rs7ue5ajEJN9wp)
#
# [Super Data Science Podcast with Jon Krohn](https://www.youtube.com/c/SuperDataSciencePodcastwithJonKrohn/videos)
#
# [The Real Python Podcast](https://www.youtube.com/watch?v=aL5GK2LVMWI&list=PLP8GkvaIxJP0zDf2TqlGkqlBOjIuzm_BJ&ab_channel=RealPython)

# %%
# import glob
# arquivos = glob.glob("*.csv")
# arquivos

# %%
# Out:
# ['pyladies.csv', 'saida_pyladies.csv']

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## ENTRADA DE DADOS

# %%
# encoding mais utilizados 'latin1', 'utf8'
df = pd.read_csv('pyladies.csv', encoding = "latin1", sep = ";",
           decimal = ",", parse_dates = ["data_atualizacao"],
           dayfirst = True)
df
# Out:
#             nome documento       sexo data_atualizacao  altura   peso
# 0          MARIA   8653287          F       2022-08-10    1.54   55,5
# 1          Celso   2058021          M       2022-09-22    1.63   74,3
# 2        Zuleide   6600351          f       2022-09-30    1.54     63
# 3           BETO   7735611  masculino       2022-06-05    1.72    102
# 4        Cecília   5842713   Feminino       2022-02-02    1.66   79,4
# 5   Ana Cristina   3504191   feminino       2022-07-16    1.64   78,6
# 6         aurora    35309A          F       2021-11-24    1.76     65
# 7            NaN   3338125  Masculino       2021-12-30    1.87   83,6
# 8       Catarina    555784   FEMININO       2022-10-01    1.62   78,4
# 9         Ângelo   8901510  masculino       2022-05-04    1.92  110,5
# 10       Vitória  65137823          F       2021-10-26    1.72
# 11         Luana   5015191          f       2021-12-08    1.67     85
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## CONHECENDO OS DADOS (ATRIBUTOS E ALGUNS MÉTODOS)

# %%
df.shape
# Out:
# (17, 6)

# %%
df.columns
# Out:
# Index(['nome', 'documento', 'sexo', 'data_atualizacao', 'altura', 'peso'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nome              15 non-null     object
#  1   documento         17 non-null     object
#  2   sexo              17 non-null     object
#  3   data_atualizacao  17 non-null     datetime64[ns]
#  4   altura            17 non-null     float64
#  5   peso              17 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 944.0+ bytes

# %%
df.isna().sum()
# Out:
# nome                2
# documento           0
# sexo                0
# data_atualizacao    0
# altura              0
# peso                0
# dtype: int64

# %%
df.describe()
# Out:
#           altura
# count  17.000000
# mean    1.696471
# std     0.109826
# min     1.540000
# 25%     1.630000
# 50%     1.660000
# 75%     1.730000
# max     1.920000

# %%
df.describe(include = 'all')
# Out:
# C:\Users\carolsvalenca\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#             nome documento       sexo     data_atualizacao     altura peso
# count         15        17         17                   17  17.000000   17
# unique        14        15         12                   17        NaN   16
# top     Catarina    555784  masculino  2022-08-10 00:00:00        NaN   85
# freq           2         2          3                    1        NaN    2
# first        NaN       NaN        NaN  2021-10-26 00:00:00        NaN  NaN
# last         NaN       NaN        NaN  2022-10-01 00:00:00        NaN  NaN
# ...

# %%
df['sexo'].value_counts()
# Out:
# masculino    3
# F            2
# feminino     2
# f            2
#  M           1
#   f          1
# Feminino     1
#   F          1
# Masculino    1
# FEMININO     1
#    m         1
# MASCULINO    1
# Name: sexo, dtype: int64

# %%
df.head(1)
# Out:
#     nome documento sexo data_atualizacao  altura  peso
# 0  MARIA   8653287    F       2022-08-10    1.54  55,5

# %%
df.tail(10)
# Out:
#         nome documento       sexo data_atualizacao  altura   peso
# 7        NaN   3338125  Masculino       2021-12-30    1.87   83,6
# 8   Catarina    555784   FEMININO       2022-10-01    1.62   78,4
# 9     Ângelo   8901510  masculino       2022-05-04    1.92  110,5
# 10   Vitória  65137823          F       2021-10-26    1.72
# 11     Luana   5015191          f       2021-12-08    1.67     85
# 12     Jorge   5013874          m       2021-12-17    1.66    115
# 13  Gabriela   1132138          f       2022-09-23    1.73     50
# 14  Catarina    555784   feminino       2022-02-11    1.62     85
# 15     JORGE   5013874  MASCULINO       2022-06-21    1.66    106
# 16       NaN   8894948  masculino       2022-04-25    1.88    126

# %%
# selecionar coluna
df['nome']
# Out:
# 0            MARIA
# 1            Celso
# 2          Zuleide
# 3             BETO
# 4          Cecília
# 5     Ana Cristina
# 6           aurora
# 7              NaN
# 8         Catarina
# 9           Ângelo
# 10         Vitória
# 11           Luana
# 12           Jorge
# 13        Gabriela
# 14        Catarina
# 15           JORGE
# 16             NaN
# Name: nome, dtype: object

# %%
df.sexo
# Out:
# 0             F
# 1             M
# 2             f
# 3     masculino
# 4      Feminino
# 5      feminino
# 6             F
# 7     Masculino
# 8      FEMININO
# 9     masculino
# 10            F
# 11            f
# 12            m
# 13            f
# 14     feminino
# 15    MASCULINO
# 16    masculino
# Name: sexo, dtype: object

# %%
df[["sexo","nome"]]
# Out:
#          sexo          nome
# 0           F         MARIA
# 1           M         Celso
# 2           f       Zuleide
# 3   masculino          BETO
# 4    Feminino       Cecília
# 5    feminino  Ana Cristina
# 6           F        aurora
# 7   Masculino           NaN
# 8    FEMININO      Catarina
# 9   masculino        Ângelo
# 10          F       Vitória
# 11          f         Luana
# 12          m         Jorge
# 13          f      Gabriela
# 14   feminino      Catarina
# 15  MASCULINO         JORGE
# 16  masculino           NaN

# %% [markdown]
# ## LIMPANDO DADOS

# %%
df
# Out:
#             nome documento       sexo data_atualizacao  altura   peso
# 0          MARIA   8653287          F       2022-08-10    1.54   55,5
# 1          Celso   2058021          M       2022-09-22    1.63   74,3
# 2        Zuleide   6600351          f       2022-09-30    1.54     63
# 3           BETO   7735611  masculino       2022-06-05    1.72    102
# 4        Cecília   5842713   Feminino       2022-02-02    1.66   79,4
# 5   Ana Cristina   3504191   feminino       2022-07-16    1.64   78,6
# 6         aurora    35309A          F       2021-11-24    1.76     65
# 7            NaN   3338125  Masculino       2021-12-30    1.87   83,6
# 8       Catarina    555784   FEMININO       2022-10-01    1.62   78,4
# 9         Ângelo   8901510  masculino       2022-05-04    1.92  110,5
# 10       Vitória  65137823          F       2021-10-26    1.72
# 11         Luana   5015191          f       2021-12-08    1.67     85
# ...

# %% [markdown]
# ### Coluna sexo : Padronizar dados e transformando para tipo category

# %%
df.value_counts()
# Out:
# nome          documento  sexo       data_atualizacao  altura  peso
# Ana Cristina  3504191    feminino   2022-07-16        1.64    78,6     1
# BETO          7735611    masculino  2022-06-05        1.72    102      1
# Catarina      555784     FEMININO   2022-10-01        1.62    78,4     1
#                          feminino   2022-02-11        1.62    85       1
# Cecília       5842713    Feminino   2022-02-02        1.66    79,4     1
# Celso         2058021     M         2022-09-22        1.63    74,3     1
# Gabriela      1132138    f          2022-09-23        1.73    50       1
# JORGE         5013874    MASCULINO  2022-06-21        1.66    106      1
# Jorge         5013874       m       2021-12-17        1.66    115      1
# Luana         5015191    f          2021-12-08        1.67    85       1
# MARIA         8653287    F          2022-08-10        1.54    55,5     1
# Vitória       65137823   F          2021-10-26        1.72             1
# ...

# %%
df['sexo']
# Out:
# 0             F
# 1             M
# 2             f
# 3     masculino
# 4      Feminino
# 5      feminino
# 6             F
# 7     Masculino
# 8      FEMININO
# 9     masculino
# 10            F
# 11            f
# 12            m
# 13            f
# 14     feminino
# 15    MASCULINO
# 16    masculino
# Name: sexo, dtype: object

# %%
df['sexo'].value_counts()
# Out:
# masculino    3
# F            2
# feminino     2
# f            2
#  M           1
#   f          1
# Feminino     1
#   F          1
# Masculino    1
# FEMININO     1
#    m         1
# MASCULINO    1
# Name: sexo, dtype: int64

# %%
a = "carol"
a
# Out:
# 'carol'

# %%
a = 'gato'
a
# Out:
# 'gato'

# %%
df['sexo'] = df['sexo'].str.strip()

# %%
df['sexo'] = df['sexo'].str.lower()
df['sexo'] = df['sexo'].replace({"f":'feminino', "m":'masculino'})
df
# Out:
#             nome documento       sexo data_atualizacao  altura   peso
# 0          MARIA   8653287   feminino       2022-08-10    1.54   55,5
# 1          Celso   2058021  masculino       2022-09-22    1.63   74,3
# 2        Zuleide   6600351   feminino       2022-09-30    1.54     63
# 3           BETO   7735611  masculino       2022-06-05    1.72    102
# 4        Cecília   5842713   feminino       2022-02-02    1.66   79,4
# 5   Ana Cristina   3504191   feminino       2022-07-16    1.64   78,6
# 6         aurora    35309A   feminino       2021-11-24    1.76     65
# 7            NaN   3338125  masculino       2021-12-30    1.87   83,6
# 8       Catarina    555784   feminino       2022-10-01    1.62   78,4
# 9         Ângelo   8901510  masculino       2022-05-04    1.92  110,5
# 10       Vitória  65137823   feminino       2021-10-26    1.72
# 11         Luana   5015191   feminino       2021-12-08    1.67     85
# ...

# %%
#df['sexo'] = df['sexo'].str.strip().str.lower().replace({"f":'feminino', "m":'masculino'})

# %%
df['sexo'].value_counts()
# Out:
# feminino     10
# masculino     7
# Name: sexo, dtype: int64

# %%
df['sexo'].value_counts(normalize = True)*100
# Out:
# feminino     58.823529
# masculino    41.176471
# Name: sexo, dtype: float64

# %%
df['sexo'] = df['sexo'].astype('category')

# %% [markdown]
# ### Coluna nome: Lidar com nulos e manipular strings

# %%
df['nome']
# Out:
# 0            MARIA
# 1            Celso
# 2          Zuleide
# 3             BETO
# 4          Cecília
# 5     Ana Cristina
# 6           aurora
# 7              NaN
# 8         Catarina
# 9           Ângelo
# 10         Vitória
# 11           Luana
# 12           Jorge
# 13        Gabriela
# 14        Catarina
# 15           JORGE
# 16             NaN
# Name: nome, dtype: object

# %%
df
# Out:
#             nome documento       sexo data_atualizacao  altura   peso
# 0          MARIA   8653287   feminino       2022-08-10    1.54   55,5
# 1          Celso   2058021  masculino       2022-09-22    1.63   74,3
# 2        Zuleide   6600351   feminino       2022-09-30    1.54     63
# 3           BETO   7735611  masculino       2022-06-05    1.72    102
# 4        Cecília   5842713   feminino       2022-02-02    1.66   79,4
# 5   Ana Cristina   3504191   feminino       2022-07-16    1.64   78,6
# 6         aurora    35309A   feminino       2021-11-24    1.76     65
# 7            NaN   3338125  masculino       2021-12-30    1.87   83,6
# 8       Catarina    555784   feminino       2022-10-01    1.62   78,4
# 9         Ângelo   8901510  masculino       2022-05-04    1.92  110,5
# 10       Vitória  65137823   feminino       2021-10-26    1.72
# 11         Luana   5015191   feminino       2021-12-08    1.67     85
# ...

# %%
df['nome'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# Name: nome, dtype: bool

# %%
"carol_" + "python"
# Out:
# 'carol_python'

# %%
# se ... então
df.loc[df['nome'].isna(), 'nome'] = "anonimo_" + df['documento']
df
# Out:
#                nome documento       sexo data_atualizacao  altura   peso
# 0             MARIA   8653287   feminino       2022-08-10    1.54   55,5
# 1             Celso   2058021  masculino       2022-09-22    1.63   74,3
# 2           Zuleide   6600351   feminino       2022-09-30    1.54     63
# 3              BETO   7735611  masculino       2022-06-05    1.72    102
# 4           Cecília   5842713   feminino       2022-02-02    1.66   79,4
# 5      Ana Cristina   3504191   feminino       2022-07-16    1.64   78,6
# 6            aurora    35309A   feminino       2021-11-24    1.76     65
# 7   anonimo_3338125   3338125  masculino       2021-12-30    1.87   83,6
# 8          Catarina    555784   feminino       2022-10-01    1.62   78,4
# 9            Ângelo   8901510  masculino       2022-05-04    1.92  110,5
# 10          Vitória  65137823   feminino       2021-10-26    1.72
# 11            Luana   5015191   feminino       2021-12-08    1.67     85
# ...

# %%
df['nome'] = df['nome'].str.title()

# %%
df
# Out:
#                nome documento       sexo data_atualizacao  altura   peso
# 0             Maria   8653287   feminino       2022-08-10    1.54   55,5
# 1             Celso   2058021  masculino       2022-09-22    1.63   74,3
# 2           Zuleide   6600351   feminino       2022-09-30    1.54     63
# 3              Beto   7735611  masculino       2022-06-05    1.72    102
# 4           Cecília   5842713   feminino       2022-02-02    1.66   79,4
# 5      Ana Cristina   3504191   feminino       2022-07-16    1.64   78,6
# 6            Aurora    35309A   feminino       2021-11-24    1.76     65
# 7   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83,6
# 8          Catarina    555784   feminino       2022-10-01    1.62   78,4
# 9            Ângelo   8901510  masculino       2022-05-04    1.92  110,5
# 10          Vitória  65137823   feminino       2021-10-26    1.72
# 11            Luana   5015191   feminino       2021-12-08    1.67     85
# ...

# %% [markdown]
# ### Coluna peso: identificar linhas com espaços, excluir essas linhas e transformar para float

# %%
df['peso']
# Out:
# 0      55,5
# 1      74,3
# 2        63
# 3       102
# 4      79,4
# 5      78,6
# 6        65
# 7      83,6
# 8      78,4
# 9     110,5
# 10
# 11       85
# 12      115
# 13       50
# 14       85
# 15      106
# 16      126
# Name: peso, dtype: object

# %%
df['peso'].isna().sum()
# Out:
# 0

# %%
df[df['peso'].str.contains(" ")]
# Out:
#        nome documento      sexo data_atualizacao  altura   peso
# 10  Vitória  65137823  feminino       2021-10-26    1.72

# %%
df[df['peso'].str.contains(" ")].index
# Out:
# Int64Index([10], dtype='int64')

# %%
# del df
#del df['sexo']

# %%
df = df.drop(df[df['peso'].str.contains(" ")].index)

# %%
df['peso'] = df['peso'].str.replace(',', ".").astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nome              16 non-null     object
#  1   documento         16 non-null     object
#  2   sexo              16 non-null     category
#  3   data_atualizacao  16 non-null     datetime64[ns]
#  4   altura            16 non-null     float64
#  5   peso              16 non-null     float64
# dtypes: category(1), datetime64[ns](1), float64(2), object(2)
# memory usage: 908.0+ bytes

# %% [markdown]
# ### Coluna documento: identificar linhas com documento repetido, classificar dataframe e excluir linhas com documento repetido

# %%
df['documento'].value_counts()
# Out:
# 555784     2
# 5013874    2
# 8653287    1
# 2058021    1
# 6600351    1
# 7735611    1
# 5842713    1
# 3504191    1
# 35309A     1
# 3338125    1
# 8901510    1
# 5015191    1
# 1132138    1
# 8894948    1
# Name: documento, dtype: int64

# %%
df[df['documento'] == '555784']
# Out:
#         nome documento      sexo data_atualizacao  altura  peso
# 8   Catarina    555784  feminino       2022-10-01    1.62  78.4
# 14  Catarina    555784  feminino       2022-02-11    1.62  85.0

# %%
df[df['documento'] == '5013874']
# Out:
#      nome documento       sexo data_atualizacao  altura   peso
# 12  Jorge   5013874  masculino       2021-12-17    1.66  115.0
# 15  Jorge   5013874  masculino       2022-06-21    1.66  106.0

# %%
df[df['documento'].duplicated()]
# Out:
#         nome documento       sexo data_atualizacao  altura   peso
# 14  Catarina    555784   feminino       2022-02-11    1.62   85.0
# 15     Jorge   5013874  masculino       2022-06-21    1.66  106.0

# %%
df[df['documento'].duplicated(keep = False)].sort_values('nome')
# Out:
#         nome documento       sexo data_atualizacao  altura   peso
# 8   Catarina    555784   feminino       2022-10-01    1.62   78.4
# 14  Catarina    555784   feminino       2022-02-11    1.62   85.0
# 12     Jorge   5013874  masculino       2021-12-17    1.66  115.0
# 15     Jorge   5013874  masculino       2022-06-21    1.66  106.0

# %%
df = df.sort_values(['nome', 'data_atualizacao'])

# %%
df = df.drop_duplicates(['nome'], keep = 'last')

# %%
df
# Out:
#                nome documento       sexo data_atualizacao  altura   peso
# 5      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 7   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 16  Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 6            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 3              Beto   7735611  masculino       2022-06-05    1.72  102.0
# 8          Catarina    555784   feminino       2022-10-01    1.62   78.4
# 4           Cecília   5842713   feminino       2022-02-02    1.66   79.4
# 1             Celso   2058021  masculino       2022-09-22    1.63   74.3
# 13         Gabriela   1132138   feminino       2022-09-23    1.73   50.0
# 15            Jorge   5013874  masculino       2022-06-21    1.66  106.0
# 11            Luana   5015191   feminino       2021-12-08    1.67   85.0
# 0             Maria   8653287   feminino       2022-08-10    1.54   55.5
# ...

# %% [markdown]
# ## CRIAR NOVA COLUNA COM VALOR CALCULADO DO IMC

# %%
df.head(1)
# Out:
#            nome documento      sexo data_atualizacao  altura  peso
# 5  Ana Cristina   3504191  feminino       2022-07-16    1.64  78.6

# %%
# o imc é calculado dividindo o peso (em kg) pela altura ao quadrado (em metros).

df['imc'] = (df['peso']/(df['altura']**2)).round(2)
df
# Out:
# C:\Users\carolsvalenca\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                nome documento       sexo data_atualizacao  altura   peso  \
# 5      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 7   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 16  Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 6            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 3              Beto   7735611  masculino       2022-06-05    1.72  102.0
# ...

# %% [markdown]
# ## CLASSIFICAR DADOS (SE ... ENTÃO)

# %% [markdown]
# Classificação IMC:
# IMC < 18,5 - abaixo do peso normal
# 18,5 <= IMC < 25 - normal
# 25 <= IMC < 30 - sobrepeso
# 30 <= IMC < 35 - obesidade
# 35 <= IMC < 40 - obesidade severa
# IMC > 40 - obseidade mórbida

# %%
condições = [
    df['imc'] < 18.5,
    df['imc'] < 25,
    df['imc'] < 30,
    df['imc'] < 35,
    df['imc'] < 40,
    df['imc'] >= 40
    
]

escolhas = [
    'abaixo do peso normal',
    'normal',
    'sobrepeso',
    'obesidade',
    'obesidade severa',
    'obesidade mórbida'
]

df['classificação'] = np.select(condições, escolhas, default = 'olhar')
df
# Out:
# C:\Users\carolsvalenca\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                nome documento       sexo data_atualizacao  altura   peso  \
# 5      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 7   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 16  Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 6            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 3              Beto   7735611  masculino       2022-06-05    1.72  102.0
# 8          Catarina    555784   feminino       2022-10-01    1.62   78.4
# 4           Cecília   5842713   feminino       2022-02-02    1.66   79.4
# ...

# %% [markdown]
# Classificação IMC Feminino:
# IMC < 19 - abaixo do peso normal
# 19 <= IMC < 24 - normal
# 24 <= IMC < 29 - sobrepeso
# 29 <= IMC < 34 - obesidade
# 34 <= IMC < 39 - obesidade severa
# IMC >= 39 - obseidade mórbida
#
# Classificação IMC Masculino:
# IMC < 20 - abaixo do peso normal
# 20 <= IMC < 25 - normal
# 25 <= IMC < 30 - sobrepeso
# 30 <= IMC < 35 - obesidade
# 35 <= IMC < 40 - obesidade severa
# IMC >= 40 - obseidade mórbida

# %% [markdown]
# # CRIAR COLUNA COM VALORES BOOLEANOS COMPARANDO OS RESULTADOS DOS DOIS TIPOS DE CLASSIFICAÇÃO DO IMC

# %%
df
# Out:
#                nome documento       sexo data_atualizacao  altura   peso  \
# 5      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 7   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 16  Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 6            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 3              Beto   7735611  masculino       2022-06-05    1.72  102.0
# 8          Catarina    555784   feminino       2022-10-01    1.62   78.4
# 4           Cecília   5842713   feminino       2022-02-02    1.66   79.4
# 1             Celso   2058021  masculino       2022-09-22    1.63   74.3
# 13         Gabriela   1132138   feminino       2022-09-23    1.73   50.0
# 15            Jorge   5013874  masculino       2022-06-21    1.66  106.0
# 11            Luana   5015191   feminino       2021-12-08    1.67   85.0
# 0             Maria   8653287   feminino       2022-08-10    1.54   55.5
# ...

# %% [markdown]
# # DELETANDO COLUNAS

# %%
df.drop(['documento'], axis = 1)
# Out:
#                nome       sexo data_atualizacao  altura   peso    imc  \
# 5      Ana Cristina   feminino       2022-07-16    1.64   78.6  29.22
# 7   Anonimo_3338125  masculino       2021-12-30    1.87   83.6  23.91
# 16  Anonimo_8894948  masculino       2022-04-25    1.88  126.0  35.65
# 6            Aurora   feminino       2021-11-24    1.76   65.0  20.98
# 3              Beto  masculino       2022-06-05    1.72  102.0  34.48
# 8          Catarina   feminino       2022-10-01    1.62   78.4  29.87
# 4           Cecília   feminino       2022-02-02    1.66   79.4  28.81
# 1             Celso  masculino       2022-09-22    1.63   74.3  27.96
# 13         Gabriela   feminino       2022-09-23    1.73   50.0  16.71
# 15            Jorge  masculino       2022-06-21    1.66  106.0  38.47
# 11            Luana   feminino       2021-12-08    1.67   85.0  30.48
# 0             Maria   feminino       2022-08-10    1.54   55.5  23.40
# ...

# %% [markdown]
# # AGREGAÇÃO DE DADOS DE TABELAS

# %%
# criar tabela com recomendações

dicionario = {'classificação_imc':['abaixo do peso normal',  'abaixo do peso normal', 'sobrepeso', 'sobrepeso','obesidades', 'obesidades', 'abaixo do peso normal'],
'sexo_paciente':['feminino', 'masculino', 'feminino','masculino', 'feminino','masculino','feminino'],
'nutricionista_recomendado':['Ana Paula',  'André', 'Carla', 'Carla', 'Carla', 'Ana Paula', 'Ana Paula'],              
'dia_atendimenoto':['segunda',  'sexta', 'quinta', 'quinta','sexta', 'segunda', 'segunda']}

recomendacao = pd.DataFrame(dicionario)
recomendacao
# Out:
#        classificação_imc sexo_paciente nutricionista_recomendado  \
# 0  abaixo do peso normal      feminino                 Ana Paula
# 1  abaixo do peso normal     masculino                     André
# 2              sobrepeso      feminino                     Carla
# 3              sobrepeso     masculino                     Carla
# 4             obesidades      feminino                     Carla
# 5             obesidades     masculino                 Ana Paula
# 6  abaixo do peso normal      feminino                 Ana Paula
#
#   dia_atendimenoto
# 0          segunda
# 1            sexta
# 2           quinta
# 3           quinta
# 4            sexta
# 5          segunda
# 6          segunda

# %%
df['classificação'].value_counts()
# Out:
# sobrepeso                6
# normal                   3
# obesidade severa         2
# obesidade                2
# abaixo do peso normal    1
# Name: classificação, dtype: int64

# %%
df['classificação'] = df['classificação'].replace({'obesidade severa':'obesidades',
                            'obesidade':'obesidades'})
# Out:
# C:\Users\carolsvalenca\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#                nome documento       sexo data_atualizacao  altura   peso  \
# 5      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 7   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 16  Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 6            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 3              Beto   7735611  masculino       2022-06-05    1.72  102.0
# 8          Catarina    555784   feminino       2022-10-01    1.62   78.4
# 4           Cecília   5842713   feminino       2022-02-02    1.66   79.4
# 1             Celso   2058021  masculino       2022-09-22    1.63   74.3
# 13         Gabriela   1132138   feminino       2022-09-23    1.73   50.0
# 15            Jorge   5013874  masculino       2022-06-21    1.66  106.0
# 11            Luana   5015191   feminino       2021-12-08    1.67   85.0
# 0             Maria   8653287   feminino       2022-08-10    1.54   55.5
# ...

# %%
recomendacao.head(1)
# Out:
#        classificação_imc sexo_paciente nutricionista_recomendado  \
# 0  abaixo do peso normal      feminino                 Ana Paula
#
#   dia_atendimenoto
# 0          segunda

# %%
df.merge(recomendacao, how ='outer',
         left_on = ['classificação', 'sexo'],
         right_on = ['classificação_imc', 'sexo_paciente'])
# Out:
#                nome documento       sexo data_atualizacao  altura   peso  \
# 0      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 1          Catarina    555784   feminino       2022-10-01    1.62   78.4
# 2           Cecília   5842713   feminino       2022-02-02    1.66   79.4
# 3           Zuleide   6600351   feminino       2022-09-30    1.54   63.0
# 4   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 5   Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 6              Beto   7735611  masculino       2022-06-05    1.72  102.0
# 7             Jorge   5013874  masculino       2022-06-21    1.66  106.0
# 8            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 9             Maria   8653287   feminino       2022-08-10    1.54   55.5
# 10            Celso   2058021  masculino       2022-09-22    1.63   74.3
# 11           Ângelo   8901510  masculino       2022-05-04    1.92  110.5
# ...

# %%
len(df)
# Out:
# 14

# %%
df.merge(recomendacao, how ='left',
         left_on = ['classificação', 'sexo'],
         right_on = ['classificação_imc', 'sexo_paciente'])
# Out:
#                nome documento       sexo data_atualizacao  altura   peso  \
# 0      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 1   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 2   Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 3            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 4              Beto   7735611  masculino       2022-06-05    1.72  102.0
# 5          Catarina    555784   feminino       2022-10-01    1.62   78.4
# 6           Cecília   5842713   feminino       2022-02-02    1.66   79.4
# 7             Celso   2058021  masculino       2022-09-22    1.63   74.3
# 8          Gabriela   1132138   feminino       2022-09-23    1.73   50.0
# 9          Gabriela   1132138   feminino       2022-09-23    1.73   50.0
# 10            Jorge   5013874  masculino       2022-06-21    1.66  106.0
# 11            Luana   5015191   feminino       2021-12-08    1.67   85.0
# ...

# %%
len(df.merge(recomendacao, how ='left',
         left_on = ['classificação', 'sexo'],
         right_on = ['classificação_imc', 'sexo_paciente']))
# Out:
# 15

# %%
recomendacao = recomendacao.drop_duplicates(['classificação_imc','sexo_paciente'])

# %%
len(df.merge(recomendacao, how ='left',
         left_on = ['classificação', 'sexo'],
         right_on = ['classificação_imc', 'sexo_paciente']))
# Out:
# 14

# %%
df = df.merge(recomendacao, how ='left',
         left_on = ['classificação', 'sexo'],
         right_on = ['classificação_imc', 'sexo_paciente'])
df
# Out:
#                nome documento       sexo data_atualizacao  altura   peso  \
# 0      Ana Cristina   3504191   feminino       2022-07-16    1.64   78.6
# 1   Anonimo_3338125   3338125  masculino       2021-12-30    1.87   83.6
# 2   Anonimo_8894948   8894948  masculino       2022-04-25    1.88  126.0
# 3            Aurora    35309A   feminino       2021-11-24    1.76   65.0
# 4              Beto   7735611  masculino       2022-06-05    1.72  102.0
# 5          Catarina    555784   feminino       2022-10-01    1.62   78.4
# 6           Cecília   5842713   feminino       2022-02-02    1.66   79.4
# 7             Celso   2058021  masculino       2022-09-22    1.63   74.3
# 8          Gabriela   1132138   feminino       2022-09-23    1.73   50.0
# 9             Jorge   5013874  masculino       2022-06-21    1.66  106.0
# 10            Luana   5015191   feminino       2021-12-08    1.67   85.0
# 11            Maria   8653287   feminino       2022-08-10    1.54   55.5
# ...

# %% [markdown]
# ## LIDAR COM VALORES CATEGÓRICOS

# %% [markdown]
# ## OBSERVAR SE OS TIPOS DE OBJETOS DAS COLUNAS FORAM MODIFICADOS COM O MERGE

# %% [markdown]
# # FILTRAR DADOS

# %% [markdown]
# # AGRUPAR

# %% [markdown]
# ## CONHECENDO O OBJETO GROUPBY

# %% [markdown]
# ## AGRUPANDO DADOS COM DIFERENTES FUNÇÕES

# %% [markdown]
# ## ATENÇÃO AO AGRUPAR COLUNAS CATEGÓRICAS!

# %% [markdown]
# # GRÁFICOS

# %% [markdown]
# # SAÍDA

# %% [markdown]
# https://www.youtube.com/watch?v=u4rsA5ZiTls&ab_channel=MedallionDataScience
